# %% [markdown]
# <a href="https://colab.research.google.com/github/Draksahil/project-demo/blob/main/Logistrict_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/insurance_data.csv')

# %%
df.head(6)
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1
# 5   56                 1

# %%
x = df['age']
y = df['bought_insurance']

# %%
x
# Out:
# 0     22
# 1     25
# 2     47
# 3     52
# 4     46
# 5     56
# 6     55
# 7     60
# 8     62
# 9     61
# 10    18
# 11    28
# 12    27
# 13    29
# 14    49
# 15    55
# 16    25
# 17    58
# 18    19
# 19    18
# 20    21
# 21    26
# 22    40
# 23    45
# 24    50
# 25    54
# 26    23
# Name: age, dtype: int64

# %%
plt.scatter(df['age'],df['bought_insurance'],color = 'green',marker = '*')

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    0
# 12    0
# 13    0
# 14    1
# 15    1
# 16    1
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    1
# 25    1
# 26    0
# Name: bought_insurance, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
import numpy as np
model.fit(x_train.values.reshape(-1, 1),y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test.values.reshape(-1, 1))
# Out:
# array([1, 0, 0])

# %%
x_test
# Out:
# 15    55
# 26    23
# 1     25
# Name: age, dtype: int64

# %%
model.score(x_test.values.reshape(-1, 1),y_test)
# Out:
# 1.0

# %%
model.coef_
# Out:
# array([[0.124733]])
